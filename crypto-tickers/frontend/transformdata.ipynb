// %%
const dotenv = require('dotenv')
const axios = require('axios')
const crypto = require('crypto')
const rateLimit = require('axios-rate-limit')
const http = rateLimit(axios.create(), { maxRPS: 1})

// %%
dotenv.config({verbose: false});
// Out:
// {
//   parsed: {
//     VUE_APP_BINANCE_API_KEY: '2PMRdBVcByWs8eKKZVF80VbwL8q6dojBt72SyzsGAOWJowqSIHYTGed7FfRIoMGK',
//     VUE_APP_BINANCE_API_SECRET: 'iHqnsMpuxOfSCdEA9BKJvp63KDuvBkbKKe8XHHSGJaubLJelvkYfZK3egU0kQMsw',
//     VUE_APP_GATEIO_API_KEY: '498d976daf238a8d5541ff475990033b',
//     VUE_APP_GATEIO_API_SECRET: '68488b65de9c39cb4aa1895f49caa0899e3febeee61c4bbe7717213ddecd9b82',
//     API_KEYS: '{ "gate":{"key": "498d976daf238a8d5541ff475990033b" ,"secret":"68488b65de9c39cb4aa1895f49caa0899e3febeee61c4bbe7717213ddecd9b82"}, "binance":{"key": "2PMRdBVcByWs8eKKZVF80VbwL8q6dojBt72SyzsGAOWJowqSIHYTGed7FfRIoMGK", "secret":"iHqnsMpuxOfSCdEA9BKJvp63KDuvBkbKKe8XHHSGJaubLJelvkYfZK3egU0kQMsw"}}'
//   }
// }

// %%
const keys = (JSON.parse(process.env.API_KEYS))

// %%
async function portfolioData() {
  await return new Promise((resolve, reject) => {
    const binanceAPI = "https://api.binance.com";
    const binanceEndpoint = "/sapi/v1/accountSnapshot";
    const gateAPI = "https://api.gateio.ws";
    const gateEndpoint = "/api/v4/spot/accounts";

    const proxyUrl = "https://thingproxy.freeboard.io/fetch/";

    let data = {
      gate: [],
      binance: [],
      combined: [],
    };

    let binanceRequestData = {};
    binanceRequestData.queryString = `type=SPOT&timestamp=${Date.now()}`;
    binanceRequestData.requestString = encodeURIComponent(
      `?${binanceRequestData.queryString}&signature=${binanceSignature(
        binanceRequestData.queryString
      )}`
    );

    const gateRequest = {
      method: "GET",
      url: `${proxyUrl}${gateAPI}${gateEndpoint}`,
      headers: gateSignature("GET", gateEndpoint, "", ""),
    };

    const binanceRequest = {
      method: "GET",
      url: `${proxyUrl}${binanceAPI}${binanceEndpoint}${binanceRequestData.requestString}`,
      headers: { "X-MBX-APIKEY": keys.binance.key },
    };

    axios
      .all([axios(gateRequest), axios(binanceRequest)])
      .then(
        axios.spread((val1, val2) => {
          val1.data.forEach((x) => {
            if(x.currency !== 'USDTEST')
              data.gate.push({
                symbol: x.currency,
                balance: x.available,
                exchange: 'gate'
              })
            })
            
          val2.data.snapshotVos
            .slice(-1)
            .pop()
            .data.balances.forEach((x) => {
              data.binance.push({
                symbol: x.asset,
                balance: x.free,
                exchange: 'binance'
              })
            });
          
          resolve({
              data: [...data.binance, ...data.gate]
          });
        })
      )
      .catch((err) => reject(err));

    function gateSignature(method, url, queryString, payloadString) {
      const hmac = crypto.createHmac("sha512", keys.gate.secret);
      const hash = crypto.createHash("sha512");

      const timestamp = Math.floor(Date.now() / 1000);

      const hashed = hash.update(payloadString || "").digest("hex");
      const sig = `${method}\n${url}\n${queryString}\n${hashed}\n${timestamp}`;
      const signed = hmac.update(sig).digest("hex");

      return { KEY: keys.gate.key, Timestamp: timestamp, SIGN: signed };
    }

    function binanceSignature(queryString) {
      return crypto
        .createHmac("sha256", keys.binance.secret)
        .update(queryString)
        .digest("hex");
    }
  });
}

// %%
async function transform(data) {
  const geckoAPI = "https://api.coingecko.com/api/v3";
  const geckoAll = "/coins/list?include_platform=false";
  const market   = "/coins/%s/market_chart/range?vs_currency=usd&from=%s&to=%s"
  const coin     = "/coins/%s?localization=false&tickers=false&market_data=false&community_data=false&developer_data=false&sparkline=false"
  const coins    = await http.get(`${geckoAPI}${geckoAll}`);

  // filter all coins from coingecko with portfolio data using symbol value
  // ary = portfolio [...symbols] array, ['ETH', 'BTC', 'ADA']

  let ary = Object.values(data.data).map((el, i, ar) => ar[i] = el.symbol.toUpperCase())
  let filtered = coins.data.filter((x) => {
    return ary.includes(x.symbol.toUpperCase()) || x.id == 'bit_financial' || x.id == 'bitcoin-free-cash'
  })

  // add coin id and name to portfolio data

  data.data.forEach((i, idx, ar) => {
    filtered.forEach(j => {
      if(i.symbol.toUpperCase() === j.symbol.toUpperCase()) {
        Object.assign(ar[idx], {id: j.id, name: j.name})
      }
    })
  })


  // filter out undefined data, only e.g. binance leverage tokens & fiat currencies
  // --> data iteration: get coin data
  // {imageurl: coingecko.imgurl, labels: [...labels], prices: [...prices]} etc etc
  // timespan change: adjust number in d2.

  data = data.data
  .filter((x) => {
    return x.id !== undefined
  })
  .map(async (x) => {
    let d1 = new Date()  
    let d2 = new Date().setDate(new Date().getDate() - 7)

    let marketQuery = util.format(market, x.id, d2 / 1000, d1 / 1000)
    let coinQuery   = util.format(coin,   x.id)

    let marketData = await http.get(geckoAPI + marketQuery)
    let coinData   = await http.get(geckoAPI + coinQuery)
    
    let returnData = {
      id:         x.id,
      symbol:     x.symbol,
      balance:    x.balance,
      imageUrl:   coinData.data.image.large.split("?")[0],
      marketData: marketData.data,
      exchange:   x.exchange
    }
    return returnData
  })

  return data
}

// %%
portfolioData().then((val) => {
  transform(val).then((val) => {
    Promise.all(val).then(val => {
      console.log(val)
    })
  })
})
// Out:
// [
//   {
//     id: 'cardano',
//     symbol: 'ADA',
//     balance: '90.7784',
//     imageUrl: 'https://assets.coingecko.com/coins/images/975/large/cardano.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'singularitynet',
//     symbol: 'AGI',
//     balance: '0.051',
//     imageUrl: 'https://assets.coingecko.com/coins/images/2138/large/singularitynet.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'aion',
//     symbol: 'AION',
//     balance: '0.008',
//     imageUrl: 'https://assets.coingecko.com/coins/images/1023/large/Aion_Currency_Symbol_Transparent_PNG.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'ankr',
//     symbol: 'ANKR',
//     balance: '981.018',
//     imageUrl: 'https://assets.coingecko.com/coins/images/4324/large/U85xTl2.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'basic-attention-token',
//     symbol: 'BAT',
//     balance: '0.0071648',
//     imageUrl: 'https://assets.coingecko.com/coins/images/677/large/basic-attention-token.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'beam',
//     symbol: 'BEAM',
//     balance: '35.03',
//     imageUrl: 'https://assets.coingecko.com/coins/images/7339/large/BEAM.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'binancecoin',
//     symbol: 'BNB',
//     balance: '0.00000681',
//     imageUrl: 'https://assets.coingecko.com/coins/images/825/large/binance-coin-logo.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'bitcoin',
//     symbol: 'BTC',
//     balance: '0.00000038',
//     imageUrl: 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'bittorrent-2',
//     symbol: 'BTT',
//     balance: '0.5',
//     imageUrl: 'https://assets.coingecko.com/coins/images/7595/large/BTT_Token_Graphic.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'binance-usd',
//     symbol: 'BUSD',
//     balance: '0.00005146',
//     imageUrl: 'https://assets.coingecko.com/coins/images/9576/large/BUSD.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'polkadot',
//     symbol: 'DOT',
//     balance: '2.68883',
//     imageUrl: 'https://assets.coingecko.com/coins/images/12171/large/aJGBjJFU_400x400.jpg',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'eos',
//     symbol: 'EOS',
//     balance: '0.0057',
//     imageUrl: 'https://assets.coingecko.com/coins/images/738/large/eos-eos-logo.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'ethereum',
//     symbol: 'ETH',
//     balance: '0',
//     imageUrl: 'https://assets.coingecko.com/coins/images/279/large/ethereum.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: '3x-long-ethereum-token',
//     symbol: 'ETHBULL',
//     balance: '0',
//     imageUrl: 'https://assets.coingecko.com/coins/images/10163/large/683JEXMN_400x400_%281%29.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'filecoin',
//     symbol: 'FIL',
//     balance: '0.62937',
//     imageUrl: 'https://assets.coingecko.com/coins/images/12817/large/filecoin.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'hydro-protocol',
//     symbol: 'HOT',
//     balance: '0.032',
//     imageUrl: 'https://assets.coingecko.com/coins/images/2570/large/Hydro-Protocol.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'litecoin',
//     symbol: 'LTC',
//     balance: '0.00000184',
//     imageUrl: 'https://assets.coingecko.com/coins/images/2/large/litecoin.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'matic-network',
//     symbol: 'MATIC',
//     balance: '0.0351',
//     imageUrl: 'https://assets.coingecko.com/coins/images/4713/large/matic___polygon.jpg',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'nano',
//     symbol: 'NANO',
//     balance: '0.00357',
//     imageUrl: 'https://assets.coingecko.com/coins/images/756/large/nano-coin-logo.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'near',
//     symbol: 'NEAR',
//     balance: '8.60139',
//     imageUrl: 'https://assets.coingecko.com/coins/images/10365/large/near_icon.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'ocean-protocol',
//     symbol: 'OCEAN',
//     balance: '28.15183',
//     imageUrl: 'https://assets.coingecko.com/coins/images/3687/large/ocean-protocol-logo.jpg',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'omisego',
//     symbol: 'OMG',
//     balance: '0.00196362',
//     imageUrl: 'https://assets.coingecko.com/coins/images/776/large/OMG_Network.jpg',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'ontology',
//     symbol: 'ONT',
//     balance: '23.84',
//     imageUrl: 'https://assets.coingecko.com/coins/images/3447/large/ONT.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'reef-finance',
//     symbol: 'REEF',
//     balance: '701.298',
//     imageUrl: 'https://assets.coingecko.com/coins/images/13504/large/Group_10572.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'siacoin',
//     symbol: 'SC',
//     balance: '0',
//     imageUrl: 'https://assets.coingecko.com/coins/images/289/large/siacoin.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'theta-fuel',
//     symbol: 'TFUEL',
//     balance: '0.6',
//     imageUrl: 'https://assets.coingecko.com/coins/images/8029/large/1_0YusgngOrriVg4ZYx4wOFQ.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'tether',
//     symbol: 'USDT',
//     balance: '0',
//     imageUrl: 'https://assets.coingecko.com/coins/images/325/large/Tether-logo.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'vechain',
//     symbol: 'VET',
//     balance: '0.809',
//     imageUrl: 'https://assets.coingecko.com/coins/images/1167/large/VeChain-Logo-768x725.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'vethor-token',
//     symbol: 'VTHO',
//     balance: '228.82624939',
//     imageUrl: 'https://assets.coingecko.com/coins/images/5230/large/vethor-token.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'ripple',
//     symbol: 'XRP',
//     balance: '0.2193',
//     imageUrl: 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'tezos',
//     symbol: 'XTZ',
//     balance: '0.00567893',
//     imageUrl: 'https://assets.coingecko.com/coins/images/976/large/Tezos-logo.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'binance'
//   },
//   {
//     id: 'chainx',
//     symbol: 'PCX',
//     balance: '1.8286211785',
//     imageUrl: 'https://assets.coingecko.com/coins/images/9133/large/chainx.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'gate'
//   },
//   {
//     id: 'darwinia-network-native-token',
//     symbol: 'RING',
//     balance: '1286.561564',
//     imageUrl: 'https://assets.coingecko.com/coins/images/9443/large/iHFgzyCK_400x400.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'gate'
//   },
//   {
//     id: 'ethereum',
//     symbol: 'ETH',
//     balance: '0.0000631179',
//     imageUrl: 'https://assets.coingecko.com/coins/images/279/large/ethereum.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'gate'
//   },
//   {
//     id: 'tether',
//     symbol: 'USDT',
//     balance: '0.00005059683',
//     imageUrl: 'https://assets.coingecko.com/coins/images/325/large/Tether-logo.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'gate'
//   },
//   {
//     id: 'wozx',
//     symbol: 'WOZX',
//     balance: '6.924124',
//     imageUrl: 'https://assets.coingecko.com/coins/images/13310/large/rZ6Oe3dm_400x400.jpg',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'gate'
//   },
//   {
//     id: 'bit_financial',
//     symbol: 'BFC',
//     balance: '376.941606',
//     imageUrl: 'https://assets.coingecko.com/coins/images/12822/large/BFC.png',
//     marketData: { prices: [Array], market_caps: [Array], total_volumes: [Array] },
//     exchange: 'gate'
//   }
// ]
